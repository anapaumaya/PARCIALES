# %%
import pandas as pd

# %%
import numpy as np

# %%
#Las llaves son consideradas como empresas
LLAVES= { "Llave 1" : [10,9.5,7,4,8.8],
         "Llave 2" : [6.1,7.7,9,5,8],
          "Llave 3 ": [1,6.5,7.7,5,8],
        }

# %%
print(LLAVES)
# Out:
# {'Llave 1': [10, 9.5, 7, 4, 8.8], 'Llave 2': [6.1, 7.7, 9, 5, 8], 'Llave 3 ': [1, 6.5, 7.7, 5, 8]}

# %%
import pandas as pd

# %%
indice=["Calificación 1", "Calificación 2","Calificación 3", "Calificación 4 ", "Calificación 5"]
Empresas=pd.DataFrame(LLAVES, index=indice)
Empresas
# Out:
#                  Llave 1  Llave 2  Llave 3
# Calificación 1      10.0      6.1       1.0
# Calificación 2       9.5      7.7       6.5
# Calificación 3       7.0      9.0       7.7
# Calificación 4       4.0      5.0       5.0
# Calificación 5       8.8      8.0       8.0

# %%
Empresas.describe()
# Out:
#          Llave 1   Llave 2  Llave 3
# count   5.000000  5.000000  5.000000
# mean    7.860000  7.160000  5.640000
# std     2.438852  1.594679  2.850088
# min     4.000000  5.000000  1.000000
# 25%     7.000000  6.100000  5.000000
# 50%     8.800000  7.700000  6.500000
# 75%     9.500000  8.000000  7.700000
# max    10.000000  9.000000  8.000000

# %%
#Te muestra el promedio de las llaves, la desviación estandar, el valor mínimo y el máximo sobre las llaves y te cuenta cuantos valores hay en cada uno de lleas, y te sale la mitad.

# %%
type("Llave 1")
# Out:
# str

# %%
Empresas.ndim
# Out:
# 2

# %%
Empresas["Llave 1"]
# Out:
# Calificación 1     10.0
# Calificación 2      9.5
# Calificación 3      7.0
# Calificación 4      4.0
# Calificación 5      8.8
# Name: Llave 1, dtype: float64

# %%
Empresas.drop(columns = 'Llave 2')
# Out:
#                  Llave 1  Llave 3
# Calificación 1      10.0       1.0
# Calificación 2       9.5       6.5
# Calificación 3       7.0       7.7
# Calificación 4       4.0       5.0
# Calificación 5       8.8       8.0

# %%
Empresas.iloc[0:2]
# Out:
#                 Llave 1  Llave 2  Llave 3
# Calificación 1     10.0      6.1       1.0
# Calificación 2      9.5      7.7       6.5

# %%
Empresas.loc[:,'Llave 1':'Llave 2']
# Out:
#                  Llave 1  Llave 2
# Calificación 1      10.0      6.1
# Calificación 2       9.5      7.7
# Calificación 3       7.0      9.0
# Calificación 4       4.0      5.0
# Calificación 5       8.8      8.0

# %%
Empresas[Empresas[ 'Llave 1']>4]
# Out:
#                 Llave 1  Llave 2  Llave 3
# Calificación 1     10.0      6.1       1.0
# Calificación 2      9.5      7.7       6.5
# Calificación 3      7.0      9.0       7.7
# Calificación 5      8.8      8.0       8.0

# %%
Empresas.columns
# Out:
# Index(['Llave 1', 'Llave 2', 'Llave 3 '], dtype='object')

# %%
Empresas[Empresas['Llave 3 ']>7]
# Out:
#                 Llave 1  Llave 2  Llave 3
# Calificación 3      7.0      9.0       7.7
# Calificación 5      8.8      8.0       8.0
